# %%
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import os
from scipy.stats import spearmanr,pearsonr
import itertools

# %%
fep1_files = ['PTP1B', 'Jnk1', 'CDK2', 'Tyk2', 'p38', 'Bace', 'MCL1', 'Thrombin']
fep2_files = ['cdk8', 'tnks2', 'hif2a', 'cmet', 'eg5', 'pfkfb3', 'shp2', 'syk']

# %% [markdown]
# # FEP1

# %%
# ====================== FEP1 ========================
def read_mol2_file(filename):
    atoms = []
    with open(filename, 'r') as f:
        all_line = f.read().split("\n")
        for line_o in all_line:
            line = line_o.rstrip().split()
            if len(line) == 2:
                if line[1] == '9':
                    
                    ind = all_line.index(line_o)
                    
                    line_without_ligands = all_line[ind+1].rstrip().split()
                    line_with_ligands = all_line[ind+2].rstrip().split()

                    return float(line_without_ligands[3]),float(line_without_ligands[5]),float(line_without_ligands[7]), \
                           float(line_with_ligands[3]),float(line_with_ligands[5]),float(line_with_ligands[7])
                
def read_mol2_file2(filename):
    atoms = []
    with open(filename, 'r') as f:
        all_line = f.read().split("\n")
        line_o  = all_line[0]
        line = line_o.rstrip().split()

        return float(line[3]),float(line[5]),float(line[7]),0,0,0               


ref_num = [2,3,4,5,6,7,8,9]
# ref_num=[6,10]
for n in ref_num:
    R = []
    S = []
    P=[]
    S_max = []
    S_min = []
    P_max = []
    P_min = []

    R2 = []
    S2 = []
    P2 = []
    S_max2 = []
    S_min2 = []
    P_max2 = []
    P_min2 = []
    R0 = []
    S0 = []
    P0 = []
    S0_max = []
    S0_min = []
    P0_max = []
    P0_min = []

    for file in fep1_files:

        r_ = 0
        r_var = 0
        s_ = 0
        s_var = 0
        p_ = 0
        p_var = 0
        
        r_2 = 0
        r_var2 = 0
        s_2 = 0
        s_var2 = 0
        p_2 = 0
        p_var2 = 0
        
        r_0 = 0
        s_0 = 0
        p_0 = 0
        r0_var = 0
        s0_var = 0
        p0_var = 0
        
        r = []
        s = []
        p = []
        r2 = []
        s2 = []
        p2 = []
        r0=[]
        s0=[]
        p0=[]
        chongfu = range(0,10)
        for cf in chongfu:
            rmse,spearman,pearson,rmse2,spearman2,pearson2 =read_mol2_file(
            f"/home/user-home/yujie/0_PBCNetv2/0_PBCNET/Result_in_paper/2.2_section/Finetune_results/{file}/ref{n}/{cf}_record.txt") 
            rmse0,spearman0,pearson0,_,_,_ =read_mol2_file2(
            f"/home/user-home/yujie/0_PBCNetv2/0_PBCNET/Result_in_paper/2.2_section/Finetune_results/{file}/ref{n}/{cf}_record.txt") 
            r.append(rmse)
            s.append(spearman)
            p.append(pearson)
            r2.append(rmse2)
            s2.append(spearman2)
            p2.append(pearson2)
            r0.append(rmse0)
            s0.append(spearman0)
            p0.append(pearson0)
            
        
        r_ += np.mean(r)
        r_var+=np.var(r)
        s_+= np.mean(s)
        s_var+=np.var(s)
        s_min = np.min(s)
        s_max = np.max(s)
        p_+= np.mean(p)
        p_var+=np.var(p)
        p_min = np.min(p)
        p_max = np.max(p)
        
        r_0 += np.mean(r0)
        s_0+= np.mean(s0)
        p_0+= np.mean(p0)
        r0_var += np.var(r0)
        s0_var += np.var(s0)
        p0_var += np.var(p0)
        s0_min = np.min(s0)
        s0_max = np.max(s0)
        p0_min = np.min(p0)
        p0_max = np.max(p0)
        S0_max.append(s0_max)
        P0_max.append(p0_max)
        S0_min.append(s0_min)
        P0_min.append(p0_min)
        
        
        
        r_2 += np.mean(r2)
        r_var2+=np.var(r2)
        s_2+= np.mean(s2)
        s_var2+=np.var(s2)
        s_min2 = np.min(s2)
        s_max2 = np.max(s2)
        p_2+= np.mean(p2)
        p_var2+=np.var(p2)
        p_min2 = np.min(p2)
        p_max2 = np.max(p2)
        
        
        R.append(r_)
        S.append(s_)
        # print(S)
        P.append(p_)
        S_max.append(s_max)
        P_max.append(p_max)
        S_min.append(s_min)
        P_min.append(p_min)
        
        R2.append(r_2)
        S2.append(s_2)
        P2.append(p_2)
        S_max2.append(s_max2)
        P_max2.append(p_max2)
        S_min2.append(s_min2)
        P_min2.append(p_min2)
        
        R0.append(r_0)
        S0.append(s_0)
        P0.append(p_0)

    print(f"{n} fep1 rmseG {np.nanmean(R)} spearman {np.nanmean(S)} pearson {np.nanmean(P)}")
    print(f"{n} fep1 rmseG {np.nanvar(R)} spearman {np.nanvar(S)} pearson {np.nanvar(P)}")
# Out:
# 2 fep1 rmseG 1.0216910117064597 spearman 0.7282680413484497 pearson 0.7211399892335789
# 2 fep1 rmseG 0.06104559676124939 spearman 0.009621861676996742 pearson 0.012255903797872655
# 3 fep1 rmseG 0.9818780093140025 spearman 0.7493413799659749 pearson 0.7476745892954786
# 3 fep1 rmseG 0.06063954055291115 spearman 0.011573284108702064 pearson 0.013310880486251488
# 4 fep1 rmseG 0.927317716307689 spearman 0.7580841419120719 pearson 0.7542958253669325
# 4 fep1 rmseG 0.05920138359737705 spearman 0.012855398354976373 pearson 0.013619957864199497
# 5 fep1 rmseG 0.8948240765766278 spearman 0.7609138014835388 pearson 0.7604794050316811
# 5 fep1 rmseG 0.058541457734893367 spearman 0.01446932642710171 pearson 0.013886192375095644
# 6 fep1 rmseG 0.8527199701035421 spearman 0.7880490516052795 pearson 0.7648928186539179
# 6 fep1 rmseG 0.044663057265063574 spearman 0.013467177019944876 pearson 0.010917222753031202
# ...

# %%
# ====================== FEP2 ========================
def read_mol2_file(filename):
    atoms = []
    with open(filename, 'r') as f:
        all_line = f.read().split("\n")
        for line_o in all_line:
            line = line_o.rstrip().split()
            if len(line) == 2:
                if line[1] == '9':
                    
                    ind = all_line.index(line_o)
                    
                    line_without_ligands = all_line[ind+1].rstrip().split()
                    line_with_ligands = all_line[ind+2].rstrip().split()

                    return float(line_without_ligands[3]),float(line_without_ligands[5]),float(line_without_ligands[7]), \
                           float(line_with_ligands[3]),float(line_with_ligands[5]),float(line_with_ligands[7])
                
def read_mol2_file2(filename):
    atoms = []
    with open(filename, 'r') as f:
        all_line = f.read().split("\n")
        line_o  = all_line[0]
        line = line_o.rstrip().split()

        return float(line[3]),float(line[5]),float(line[7]),0,0,0               


ref_num = [2,3,4,5,6,7,8,9,10]
# ref_num=[2]
for n in ref_num:



    R = []
    S = []
    P=[]
    S_max = []
    S_min = []
    P_max = []
    P_min = []

    R2 = []
    S2 = []
    P2 = []
    S_max2 = []
    S_min2 = []
    P_max2 = []
    P_min2 = []
    R0 = []
    S0 = []
    P0 = []
    S0_max = []
    S0_min = []
    P0_max = []
    P0_min = []
    # print(n)


    for file in fep2_files:
        chongfu = [i for i in range(0,10)]

        r_ = 0
        r_var = 0
        s_ = 0
        s_var = 0
        p_ = 0
        p_var = 0
        
        r_2 = 0
        r_var2 = 0
        s_2 = 0
        s_var2 = 0
        p_2 = 0
        p_var2 = 0
        
        r_0 = 0
        s_0 = 0
        p_0 = 0
        r0_var = 0
        s0_var = 0
        p0_var = 0
        
        r = []
        s = []
        p = []
        r2 = []
        s2 = []
        p2 = []
        r0=[]
        s0=[]
        p0=[]
        for cf in chongfu:
            rmse,spearman,pearson,rmse2,spearman2,pearson2 =read_mol2_file(
            f"/home/user-home/yujie/0_PBCNetv2/0_PBCNET/Result_in_paper/2.2_section/Finetune_results/{file}/ref{n}/{cf}_record.txt") 
            rmse0,spearman0,pearson0,_,_,_ =read_mol2_file2(
            f"/home/user-home/yujie/0_PBCNetv2/0_PBCNET/Result_in_paper/2.2_section/Finetune_results/{file}/ref{n}/{cf}_record.txt") 
            r.append(rmse)
            s.append(spearman)
            p.append(pearson)
            r2.append(rmse2)
            s2.append(spearman2)
            p2.append(pearson2)
            r0.append(rmse0)
            s0.append(spearman0)
            p0.append(pearson0)
        
        r_ += np.mean(r)
        r_var+=np.var(r)
        s_+= np.mean(s)
        s_var+=np.var(s)
        s_min = np.min(s)
        s_max = np.max(s)
        p_+= np.mean(p)
        p_var+=np.var(p)
        p_min = np.min(p)
        p_max = np.max(p)
        
        r_0 += np.mean(r0)
        s_0+= np.mean(s0)
        p_0+= np.mean(p0)
        r0_var += np.var(r0)
        s0_var += np.var(s0)
        p0_var += np.var(p0)
        s0_min = np.min(s0)
        s0_max = np.max(s0)
        p0_min = np.min(p0)
        p0_max = np.max(p0)
        S0_max.append(s0_max)
        P0_max.append(p0_max)
        S0_min.append(s0_min)
        P0_min.append(p0_min)
        
        
        
        r_2 += np.mean(r2)
        r_var2+=np.var(r2)
        s_2+= np.mean(s2)
        s_var2+=np.var(s2)
        s_min2 = np.min(s2)
        s_max2 = np.max(s2)
        p_2+= np.mean(p2)
        p_var2+=np.var(p2)
        p_min2 = np.min(p2)
        p_max2 = np.max(p2)
        
        
        R.append(r_)
        S.append(s_)
        # print(S)
        P.append(p_)
        S_max.append(s_max)
        P_max.append(p_max)
        S_min.append(s_min)
        P_min.append(p_min)
        
        R2.append(r_2)
        S2.append(s_2)
        P2.append(p_2)
        S_max2.append(s_max2)
        P_max2.append(p_max2)
        S_min2.append(s_min2)
        P_min2.append(p_min2)
        
        R0.append(r_0)
        S0.append(s_0)
        P0.append(p_0)


    print(f"{n} fep2 rmseG {np.nanmean(R)} spearman {np.nanmean(S)} pearson {np.nanmean(P)}")
    print(f"{n} fep2 rmseG {np.nanvar(R)} spearman {np.nanvar(S)} pearson {np.nanvar(P)}")
# Out:
# 2 fep2 rmseG 1.1524110001036225 spearman 0.648395711027773 pearson 0.6430138839484919
# 2 fep2 rmseG 0.06480074477061834 spearman 0.02050257741452517 pearson 0.02323287787247591
# 3 fep2 rmseG 1.0763443481586674 spearman 0.6791321534750063 pearson 0.6681805558262248
# 3 fep2 rmseG 0.04784426158458718 spearman 0.016397784563242705 pearson 0.018817970501253323
# 4 fep2 rmseG 1.0551889335324807 spearman 0.679254568014692 pearson 0.6700067867436656
# 4 fep2 rmseG 0.05422072383209395 spearman 0.017269229105141157 pearson 0.019951667716344223
# 5 fep2 rmseG 1.0517029527396478 spearman 0.6971663508437109 pearson 0.6731345200078499
# 5 fep2 rmseG 0.05967967715043321 spearman 0.018325939250217006 pearson 0.02123984691191477
# 6 fep2 rmseG 1.0158944617899266 spearman 0.7012353422936202 pearson 0.6761290227353214
# 6 fep2 rmseG 0.03848587201113637 spearman 0.017153789582568562 pearson 0.02025103397229614
# 7 fep2 rmseG 1.0287281938535862 spearman 0.70421237013312 pearson 0.6857769572697279
# ...

# %%
#PBCnet:

# FEP1 Pearson
y=[0.648,0.663,0.680,0.702,0.703,0.729,0.739,0.755]
ye = [0.001,0.009,0.007,0.006,0.005,0.009,0.011,0.013] * 10
# FEP1 Spearman
y=[0.636,0.679,0.700,0.724,0.737,0.742,0.755,0.757,0.774]
ye = [0.002,0.009,0.01,0.008,0.01,0.012,0.007,0.016,0.016] * 10

# FEP2 Pearson
y=[0.468,
0.527,
0.534,
0.556,
0.571,
0.592,
0.598,
0.613,
0.623,
0.646]
ye = [0.003,
0.031,
0.029,
0.031,
0.028,
0.031,
0.028,
0.03,
0.032,
0.029] * 10

# FEP2 Spearman
y = [0.513,0.575,0.577,0.605,0.614,0.629,0.627,0.635,0.643,0.657]
ye = [0.002,0.022,0.021,0.012,0.017,0.020,0.018,0.020,0.025,0.025] * 10
